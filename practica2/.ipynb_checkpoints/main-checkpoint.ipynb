# %% [markdown]
# <font size=10>**Pràctica 2**</font>
#
#
#
#
# Lluís Picornell Company<br/>
# 43477189J<br/>
# Xavier Vives Marcus<br/>
# 43462573W<br/>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Llegim dades
dades = pd.read_csv('dades.csv')
print(dades.columns.values)
# Llevam columnes 'PassengerId' , 'Name' i 'Ticket' Ja que no aporten cap informació
dades.drop(dades.columns[0],axis=1,inplace=True)
dades.drop(dades.columns[2],axis=1,inplace=True)
dades.drop(dades.columns[6],axis=1,inplace=True)

print(dades.columns.values)

# Substituim valors female/male per 0 o 1 a la columna 'Sex'
dades['Sex'].replace('female', 0,inplace=True)
dades['Sex'].replace('male', 1,inplace=True)


# Comprovam la quantitat de NaNs  que hi ha al nostre df
print(dades.info())
# Podem veure que la columna 'Cabin' només té 204 registres d'un total de 891 registres que no son nulls.
# Per tant, eliminam la columna 'Cabin'
dades.drop(dades.columns[7],axis=1,inplace=True)

# Substituim els valors NaN de la columna 'Age' per la mitjana de 'Age'
dades['Age'].fillna(dades['Age'].mode()[0], inplace = True)

# Canviam la columna Embarked per Embarked_C , Embarked_S i Embarked_Q
clb = dades.pop("Embarked")
ohe_clb = pd.get_dummies(clb, prefix='Embarked')
dades = pd.concat([dades.reset_index(drop=True), ohe_clb.reset_index(drop=True)], axis=1, sort=False)

# Anem a veure com de relacionades estan les dades
sns.heatmap(dades.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# Podem veure que 'SibSp' , 'Parch' i 'Age' no estan gens relacionades amb 'Survive' (que és la que ens interessa).
# per tant, les llevam.
dades.drop(dades.columns[3],axis=1,inplace=True)
dades.drop(dades.columns[3],axis=1,inplace=True)
dades.drop(dades.columns[3],axis=1,inplace=True)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']
# ['Survived' 'Pclass' 'Sex' 'Age' 'SibSp' 'Parch' 'Fare' 'Cabin' 'Embarked']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB
# None
#      Survived  Pclass  Sex     Fare  Embarked_C  Embarked_Q  Embarked_S
# 0           0       3    1   7.2500           0           0           1
# ...
